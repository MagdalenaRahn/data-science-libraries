# %%
from pydataset import data
import pandas as pd
import numpy as np

# %%
# data('mpg', show_doc = True) 
# view the documentation for the dataset

mpg = data('mpg') 
# load the dataset and store it in a variable

# %%
# Set-up

students = ['Serena', 'Johannes', 'Suzette', 'Boyan', 'Ada', 'Yassen', 'Thomas',
            'Mario', 'Alberta', 'Ricardo', 'Isaak', 'Alain']

# math
math_grades = np.random.randint(low = 60, high = 100, size = len(students))


#english
english_grades = np.random.randint(low = 60, high = 100, size = len(students))


#reading
reading_grades = np.random.randint(low = 60, high = 100, size = len(students))

df = pd.DataFrame(
                {'name': students,
                'math': math_grades,
                'english': english_grades,
                'reading': reading_grades}
                    )

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 1a 
# Create a column named passing_english that indicates whether each student has a passing grade in English.


df['passing_english'] = df.english >= 69
df
# Out:
#         name  math  english  reading  passing_english
# 0     Serena    72       77       77             True
# 1   Johannes    87       66       97            False
# 2    Suzette    64       70       76             True
# 3      Boyan    68       95       94             True
# 4        Ada    99       68       78            False
# 5     Yassen    73       72       69             True
# 6     Thomas    88       89       72             True
# 7      Mario    78       66       88            False
# 8    Alberta    97       85       97             True
# 9    Ricardo    66       88       83             True
# 10     Isaak    62       71       66             True
# 11     Alain    75       77       86             True

# %%
#1b 
# Sort the english grades by the passing_english column. How are duplicates handled?

# Duplicates are sorted by T/F

df.sort_values('passing_english', ascending = True)

# or (by = 'passing_english')
# Out:
#         name  math  english  reading  passing_english  overall_grade
# 1   Johannes    87       66       97            False           83.3
# 4        Ada    99       68       78            False           81.7
# 7      Mario    78       66       88            False           77.3
# 0     Serena    72       77       77             True           75.3
# 2    Suzette    64       70       76             True           70.0
# 3      Boyan    68       95       94             True           85.7
# 5     Yassen    73       72       69             True           71.3
# 6     Thomas    88       89       72             True           83.0
# 8    Alberta    97       85       97             True           93.0
# 9    Ricardo    66       88       83             True           79.0
# 10     Isaak    62       71       66             True           66.3
# 11     Alain    75       77       86             True           79.3

# %%
# 1c 
# Sort the english grades first by passing_english and then by student name. All the students that 
# are failing english should be first, and within the students that are failing english they should 
# be ordered alphabetically. The same should be true for the students passing english. 
# (Hint: you can pass a list to the .sort_values method)

df.sort_values(by = ['passing_english', 'name'])
# Out:
#         name  math  english  reading  passing_english
# 4        Ada    99       68       78            False
# 1   Johannes    87       66       97            False
# 7      Mario    78       66       88            False
# 11     Alain    75       77       86             True
# 8    Alberta    97       85       97             True
# 3      Boyan    68       95       94             True
# 10     Isaak    62       71       66             True
# 9    Ricardo    66       88       83             True
# 0     Serena    72       77       77             True
# 2    Suzette    64       70       76             True
# 6     Thomas    88       89       72             True
# 5     Yassen    73       72       69             True

# %%
# 1d
# Sort the english grades first by passing_english, and then 
# by the actual english grade, similar to how we did in the last step.

df.sort_values(['english'])

# or (['passing_english', 'english'])
# Out:
#         name  math  english  reading  passing_english  overall_grade
# 1   Johannes    87       66       97            False           83.3
# 7      Mario    78       66       88            False           77.3
# 4        Ada    99       68       78            False           81.7
# 2    Suzette    64       70       76             True           70.0
# 10     Isaak    62       71       66             True           66.3
# 5     Yassen    73       72       69             True           71.3
# 0     Serena    72       77       77             True           75.3
# 11     Alain    75       77       86             True           79.3
# 8    Alberta    97       85       97             True           93.0
# 9    Ricardo    66       88       83             True           79.0
# 6     Thomas    88       89       72             True           83.0
# 3      Boyan    68       95       94             True           85.7

# %%
# 1e
# Calculate each student's overall grade and add it as a column on the dataframe. 
# The overall grade is the average of the math, english, and reading grades.

df['overall_grade'] = round((df.english + df.math + df.reading) / 3, 1)
df.sort_values(by = 'overall_grade')
# Out:
#         name  math  english  reading  passing_english  overall_grade
# 10     Isaak    62       71       66             True           66.3
# 2    Suzette    64       70       76             True           70.0
# 5     Yassen    73       72       69             True           71.3
# 0     Serena    72       77       77             True           75.3
# 7      Mario    78       66       88            False           77.3
# 9    Ricardo    66       88       83             True           79.0
# 11     Alain    75       77       86             True           79.3
# 4        Ada    99       68       78            False           81.7
# 6     Thomas    88       89       72             True           83.0
# 1   Johannes    87       66       97            False           83.3
# 3      Boyan    68       95       94             True           85.7
# 8    Alberta    97       85       97             True           93.0

# %%
# 1 e, alt (in-class)

df['overall_grade'] = round((df['math'] + df['english'] + df['reading'])/3, 1)
df.sort_values('overall_grade')
# Out:
#         name  math  english  reading  passing_english  overall_grade
# 10     Isaak    62       71       66             True           66.3
# 2    Suzette    64       70       76             True           70.0
# 5     Yassen    73       72       69             True           71.3
# 0     Serena    72       77       77             True           75.3
# 7      Mario    78       66       88            False           77.3
# 9    Ricardo    66       88       83             True           79.0
# 11     Alain    75       77       86             True           79.3
# 4        Ada    99       68       78            False           81.7
# 6     Thomas    88       89       72             True           83.0
# 1   Johannes    87       66       97            False           83.3
# 3      Boyan    68       95       94             True           85.7
# 8    Alberta    97       85       97             True           93.0

# %%
# 2
# a / How many rows and columns are there?
# b / What are the data types of each column?
# c / Summarize the dataframe with .info and .describe

# %%
data('mpg', show_doc = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 data('mpg', show_doc = True)
#
# NameError: name 'data' is not defined

# %%
# a 
mpg.shape
# Out:
# (234, 11)

# %%
# b
type(mpg)
# Out:
# pandas.core.frame.DataFrame

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
# c
mpg.info()

# manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
# c
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
# 2 d
# Rename the cty column to city.

mpg_city = mpg.rename(columns = {'cty': 'city'})
mpg_city

# or mpg_city = mpg.rename(columns = {'cty': 'city'}, inplace = True) 
# the 'inplace = True' sets the new column name permanently
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
# 2 e
# Do any cars have better city mileage than highway mileage?

mpg_city[mpg_city.city > mpg_city.hwy].sort_values(by = 'city')

# this returns a blank column header
# I don't understand how the average city or hwy mpg would answer the question.
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, hwy, fl, class]
# Index: []

# %%
round(mpg_city.city.mean(), 2)
# Out:
# 16.86

# %%
round(mpg_city.hwy.mean(), 2)
# Out:
# 23.44

# %%
mpg_city.sort_values(by = 'city')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 100        honda                civic    1.6  1999    4  manual(m5)   f    28
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
#
# ...

# %%
# 2 e, in-class

sum(mpg_city['city'] > mpg['hwy'])
# Out:
# 0

# %%
# 2 e, in-class

[mpg_city['city'] > mpg['hwy']]

# returns a boolean true / false
# Out:
# [1      False
#  2      False
#  3      False
#  4      False
#  5      False
#         ...
#  230    False
#  231    False
#  232    False
#  233    False
#  234    False
#  Length: 234, dtype: bool]

# %%
# 2 f , in-clas
mpg_city['mileage_difference'] = mpg_city['hwy'] - mpg_city['city']

mpg_city.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11               47
# 2                   8               50
# 3                  11               51
# 4                   9               51
# 5                  10               42

# %%
# 2 f , in-clas, continued

mpg_city.sort_values('mileage_difference', ascending = False).head()
# or : mpg_city.sort_values('mileage_difference').tail()
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29   41  d
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18   29  p
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18   29  p
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18   29  r
#
#           class  mileage_difference  average_mileage
# 107  subcompact                  12               60
# 223  subcompact                  12               70
# 1       compact                  11               47
# 229     midsize                  11               47
# 36      midsize                  11               47

# %%
# 2 f
# Create a column named mileage_difference. This column should contain the difference between 
#  highway and city mileage for each car.

mpg_city['mileage_difference'] = mpg_city.hwy - mpg_city.city
mpg_city
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# ...

# %%
mpg_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        234 non-null    object
#  1   model               234 non-null    object
#  2   displ               234 non-null    float64
#  3   year                234 non-null    int64
#  4   cyl                 234 non-null    int64
#  5   trans               234 non-null    object
#  6   drv                 234 non-null    object
#  7   city                234 non-null    int64
#  8   hwy                 234 non-null    int64
#  9   fl                  234 non-null    object
#  10  class               234 non-null    object
#  11  mileage_difference  234 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 23.8+ KB

# %%
# 2 g
# Which car (or cars) has the highest mileage difference?

mpg_city.sort_values('mileage_difference').tail(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       1 # 2 g
#       2 # Which car (or cars) has the highest mileage difference?
# ----> 4 mpg_city.sort_values('mileage_difference').tail(5)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6322, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6318 elif len(by):
# ...

# %%
# 2h, Which compact class car has the lowest highway mileage? The best?

hwyclass = mpg_city.sort_values(by = ['hwy', 'class'])
hwyclass
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 107        honda                civic    1.8  2008    4    auto(l5)   f    24
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
#
# ...

# %%
# 2 h, in-class
mpg_city['class']
# Out:
# 1      compact
# 2      compact
# 3      compact
# 4      compact
# 5      compact
#         ...
# 230    midsize
# 231    midsize
# 232    midsize
# 233    midsize
# 234    midsize
# Name: class, Length: 234, dtype: object

# %%
# 2 h, in-class, cont
mpg_city[mpg_city['class'] == 'compact']
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  hwy  \
# 1           audi            a4    1.8  1999    4    auto(l5)   f    18   29
# 2           audi            a4    1.8  1999    4  manual(m5)   f    21   29
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20   31
# 4           audi            a4    2.0  2008    4    auto(av)   f    21   30
# 5           audi            a4    2.8  1999    6    auto(l5)   f    16   26
# 6           audi            a4    2.8  1999    6  manual(m5)   f    18   26
# 7           audi            a4    3.1  2008    6    auto(av)   f    18   27
# 8           audi    a4 quattro    1.8  1999    4  manual(m5)   4    18   26
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4    16   25
# 10          audi    a4 quattro    2.0  2008    4  manual(m6)   4    20   28
# 11          audi    a4 quattro    2.0  2008    4    auto(s6)   4    19   27
# ...

# %%
# 2 h, in-class, cont

mpg_city[mpg_city['class'] == 'compact'].sort_values('hwy').head()
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  city  hwy fl  \
# 220   volkswagen        jetta    2.8  1999    6    auto(l4)   f    16   23  r
# 221   volkswagen        jetta    2.8  1999    6  manual(m5)   f    17   24  r
# 212   volkswagen          gti    2.8  1999    6  manual(m5)   f    17   24  r
# 172       subaru  impreza awd    2.5  2008    4  manual(m5)   4    19   25  p
# 170       subaru  impreza awd    2.5  2008    4    auto(s4)   4    20   25  p
#
#        class
# 220  compact
# 221  compact
# 212  compact
# 172  compact
# 170  compact

# %%
# 2 h, in-class, cont

mpg_city[mpg_city['class'] == 'compact'].sort_values('hwy', ascending = False).head()
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  city  hwy fl  \
# 213   volkswagen    jetta    1.9  1999    4  manual(m5)   f    33   44  d
# 197       toyota  corolla    1.8  2008    4  manual(m5)   f    28   37  r
# 196       toyota  corolla    1.8  1999    4  manual(m5)   f    26   35  r
# 198       toyota  corolla    1.8  2008    4    auto(l4)   f    26   35  r
# 195       toyota  corolla    1.8  1999    4    auto(l4)   f    24   33  r
#
#        class
# 213  compact
# 197  compact
# 196  compact
# 198  compact
# 195  compact

# %%
# 2 i 
# Create a column named average_mileage that is the mean of the city and highway mileage.

aver = mpg_city['average_mileage'] = mpg_city.city.mean() + mpg_city.hwy.mean()
aver

# This returns the same 'average_mileage' for each vehicle, of 40.299145.
# Out:
# 40.299145299145295

# %%
# 2 i 

mpg_city[mpg_city['average_mileage'] == (mpg_city.city.mean() + mpg_city.hwy.mean())]
mpg_city


# This returns the total mileage of each vehicle (city + hwy).
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference  average_mileage
# ...

# %%
round(mpg_city.groupby('class').mean(), 2)
# Out:
#             displ     year   cyl   city    hwy  mileage_difference  \
# class
# 2seater      6.16  2004.40  8.00  15.40  24.80                9.40
# compact      2.33  2003.21  4.60  20.13  28.30                8.17
# midsize      2.92  2003.61  5.32  18.76  27.29                8.54
# minivan      3.39  2003.09  5.82  15.82  22.36                6.55
# pickup       4.42  2003.64  7.03  13.00  16.88                3.88
# subcompact   2.66  2003.11  5.03  20.37  28.14                7.77
# suv          4.46  2003.79  6.97  13.50  18.13                4.63
#
#             average_mileage
# class
# 2seater               40.20
# compact               48.43
# midsize               46.05
# minivan               38.18
# pickup                29.88
# subcompact            48.51
# suv                   31.63

# %%
# 2 i , in-cllass

mpg_city['average_mileage'] = (mpg_city['city'] + mpg_city['hwy']) / 2

mpg_city.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact
#
#    average_mileage
# 1             23.5
# 2             25.0
# 3             25.5
# 4             25.5
# 5             21.0

# %%
# 2 j
# Which dodge car has the best average mileage? The worst?

mpg_city[{'manufacturer' :'dodge'}]
# Out:
# /var/folders/v1/7y2hc6q17wl2rjlpg8h9g78h0000gn/T/ipykernel_1928/3458828051.py:4: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   mpg_city[{'manufacturer' :'dodge'}]
#     manufacturer
# 1           audi
# 2           audi
# 3           audi
# 4           audi
# 5           audi
# ..           ...
# 230   volkswagen
# 231   volkswagen
# 232   volkswagen
# 233   volkswagen
# 234   volkswagen
#
# [234 rows x 1 columns]

# %%
# 2 j, in-class

mpg_city[mpg_city['manufacturer'] == 'dodge'].head()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18   24  r
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17   24  r
# 40        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16   22  r
# 41        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16   22  r
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17   24  r
#
#       class  average_mileage
# 38  minivan             21.0
# 39  minivan             20.5
# 40  minivan             19.0
# 41  minivan             19.0
# 42  minivan             20.5

# %%
# 2 j, in-class, cont

mpg_city[mpg_city['manufacturer'] == 'dodge'].sort_values('average_mileage').head()
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
#
#     hwy fl   class  average_mileage
# 70   12  e  pickup             10.5
# 66   12  e  pickup             10.5
# 60   12  e     suv             10.5
# 55   12  e  pickup             10.5
# 74   15  r  pickup             13.0

# %%
mpg_city[mpg_city['manufacturer'] == 'dodge'].sort_values('average_mileage').tail()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  hwy fl  \
# 48        dodge  caravan 2wd    4.0  2008    6  auto(l6)   f    16   23  r
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17   24  r
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17   24  r
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17   24  r
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18   24  r
#
#       class  average_mileage
# 48  minivan             19.5
# 43  minivan             20.5
# 42  minivan             20.5
# 39  minivan             20.5
# 38  minivan             21.0

# %% [markdown]
# ## Mammals

# %%
data('Mammals', show_doc = True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
# 3 a 
# How many rows and columns are there?

mammals = data('Mammals')

mammals.shape

# rows = 0th axis, columns = 1st axis
# Out:
# (107, 4)

# %%
# 3 b 
# What are the data types?
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# 3 c
# Summarize the dataframe with .info and .describe

mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
# 3 c
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# 3 d
# What is the the weight of the fastest animal?

mammals.sort_values('speed', ascending = False).head()
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False
# 39    37.0  105.0    False     False
# 35    50.0  100.0    False     False
# 41    34.0   97.0    False     False
# 42    30.0   97.0    False     False

# %%
# 3 e
# What is the overal percentage of specials?
 
num_specials = len(mammals[mammals['specials'] == True])

pct_specials = num_specials / len(mammals) * 100

round(pct_specials, 2)
# Out:
# 9.35

# %%
mammals.specials.sum() / len(mammals) * 100

# this T / F in a column, summed, is true instances in column
# Out:
# 9.345794392523365

# %%
# 3 f
# How many animals are hoppers that are above the median speed? What percentage is this?

mammals[mammals['hoppers']]

# mammals[mammals['hoppers'] == True] --> this is the same
# Out:
#      weight  speed  hoppers  specials
# 82    0.056   21.0     True     False
# 85    0.035   32.0     True     False
# 86    0.035   14.0     True     False
# 96    4.600   64.0     True     False
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 99    3.500   56.0     True     False
# 100   2.000   64.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False

# %%
# 3 f, cont
mammals[mammals['hoppers']].sort_values('speed')

# %%
# 3 f, cont
mammals['speed'].median()
# Out:
# 48.0

# %%
# 3 f, cont

hoppers = mammals[mammals['hoppers']]
hoppers > mammals['speed'].median()
# Out:
#      weight  speed  hoppers  specials
# 82    False  False    False     False
# 85    False  False    False     False
# 86    False  False    False     False
# 96    False   True    False     False
# 97    False   True    False     False
# 98    False   True    False     False
# 99    False   True    False     False
# 100   False   True    False     False
# 101   False   True    False     False
# 102   False   True    False     False
# 103   False  False    False     False

# %%
# 3 f, cont

hoppers[hoppers['speed'] > mammals['speed'].median()]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
# 3 f, cont

fast_hoppers = len(hoppers[hoppers['speed'] > mammals['speed'].median()])
fast_hoppers / len(mammals) * 100
# Out:
# 6.5420560747663545

# %%
#what pc of hoppers are faster than the median speed of all the hoppers ?

round(fast_hoppers / len(hoppers) * 100, 2)
# Out:
# 63.64

# %% [markdown]
# # a graph of data
#
#  data(Mammals)
#     attach(Mammals)
#     x <- log(weight)
#     y <- log(speed)
#     plot(x,y, xlab="Weight in log(Kg)", ylab="Speed in log(Km/hour)",type="n")
#     points(x[hoppers],y[hoppers],pch = "h", col="red")
#     points(x[specials],y[specials],pch = "s", col="blue")
#     others <- (!hoppers & !specials)
#     points(x[others],y[others], col="black",cex = .75)
#     fit <- rqss(y ~ qss(x, lambda = 1),tau = .9)
#     plot(fit)

# %%
mammals.plot()
# Out:
# <AxesSubplot:>

# %%
mammals.plot.scatter(x = 'weight', y = 'speed')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='speed'>
